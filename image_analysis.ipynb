# %% [markdown]
# # Image Analysis V4.0 Captioning and Dense Captioning (public preview)
#
# "Caption" replaces "Describe" in V4.0 as the significantly improved image captioning feature rich with details and sematic understanding.
#
# - Dense Captions provides more detail by generating one sentence descriptions of up to 10 regions of the image in addition to describing the whole image.
# - Dense Captions also returns bounding box coordinates of the described image regions.
# - There's also a new gender-neutral parameter to allow customers to choose whether to enable probabilistic gender inference for alt-text and Seeing AI applications.
# - Automatically deliver rich captions, accessible alt-text, SEO optimization, and intelligent photo curation to support digital content.
#
# https://learn.microsoft.com/en-us/azure/cognitive-services/computer-vision/concept-describe-images-40?tabs=image

# %%
import cv2
import json
import datetime
import requests
import sys
import random
import urllib.request
import numpy as np
import ipyplot
import glob

from io import BytesIO
from PIL import Image
from matplotlib import pyplot as plt

# %%
sys.version
# Out:
# '3.11.8 (main, Mar 18 2024, 11:56:40) [Clang 15.0.0 (clang-1500.3.9.4)]'

# %%
print("Today is", datetime.datetime.today())
# Out:
# Today is 2024-08-16 06:59:14.371380

# %%
import os
myendpoint= os.environ['MY_URL']
myendpoint_key1= os.environ['MY_KEY']
endpoint = myendpoint+"computervision/imageanalysis:analyze?api-version=2023-02-01-preview&features=denseCaptions&language=en"

headers = {
    'Content-type': 'application/json',
    'Ocp-Apim-Subscription-Key': myendpoint_key1
}

# %%
imageurl = 'https://github.com/retkowsky/images/blob/master/car%20on%20fire.jpg?raw=true'

r = requests.get(imageurl)
img = Image.open(BytesIO(r.content))
img

img.save("image1.jpg")

# %%
r = requests.post(endpoint,
                  data=json.dumps({'url': imageurl}),
                  headers=headers)

# # Open the image file in binary mode
# import base64


# image_path = 'sample_image.png'
# compressed_image_path = 'sample_image_compressed1.png'
# compressed_image_path2= 'sample_image_compressed2.png'

# # Open the original image
# with Image.open(image_path) as img:
#     # Compress the image (e.g., reduce quality for JPEG)
#     img.save(compressed_image_path, format='PNG', optimize=True)

# with Image.open(compressed_image_path) as img:
#     # Compress the image (e.g., reduce quality for JPEG)
#     img.save(compressed_image_path2, format='PNG', optimize=True)

# # Read and encode the compressed image
# with open(compressed_image_path2, 'rb') as image_file:
#     encoded_image = base64.b64encode(compressed_image_path2.read()).decode('utf-8')

# # Create a JSON object with the base64-encoded image
# image_json = {
#     'image': encoded_image
# }

# # Convert the JSON object to a JSON string
# json_string = json.dumps(image_json, indent=4)

# # Output the JSON string (you can also save it to a file)
# print(json_string)

# r = requests.post(endpoint,
#                   data=json.dumps(image_json, indent=4),
#                   headers=headers)

results = r.json()
results
# Out:
# {'denseCaptionsResult': {'values': [{'text': 'a fire truck and a car on fire',
#     'confidence': 0.7798057198524475,
#     'boundingBox': {'x': 0, 'y': 0, 'w': 1200, 'h': 602}},
#    {'text': 'a fire truck on the road',
#     'confidence': 0.786890983581543,
#     'boundingBox': {'x': 332, 'y': 322, 'w': 185, 'h': 114}},
#    {'text': 'a car on fire with smoke coming out of the back',
#     'confidence': 0.7961422204971313,
#     'boundingBox': {'x': 670, 'y': 401, 'w': 187, 'h': 117}},
#    {'text': 'a green sign with white text',
#     'confidence': 0.7752601504325867,
#     'boundingBox': {'x': 199, 'y': 301, 'w': 73, 'h': 64}},
#    {'text': 'a green sign with a white arrow',
#     'confidence': 0.8083931803703308,
#     'boundingBox': {'x': 199, 'y': 300, 'w': 73, 'h': 152}},
#    {'text': 'a car parked on the side of a road',
#     'confidence': 0.7894208431243896,
#     'boundingBox': {'x': 792, 'y': 244, 'w': 399, 'h': 349}},
#    {'text': 'a person wearing a firefighter uniform',
#     'confidence': 0.6900274753570557,
#     'boundingBox': {'x': 454, 'y': 405, 'w': 51, 'h': 70}},
#    {'text': 'a fire truck on the road',
#     'confidence': 0.7976521253585815,
#     'boundingBox': {'x': 96, 'y': 72, 'w': 386, 'h': 346}},
#    {'text': 'firemen on the road with a fire truck',
#     'confidence': 0.6349040865898132,
#     'boundingBox': {'x': 75, 'y': 150, 'w': 728, 'h': 431}},
#    {'text': 'a pole with a light on it',
#     'confidence': 0.6695119142532349,
#     'boundingBox': {'x': 1013, 'y': 1, 'w': 122, 'h': 287}}]},
#  'modelVersion': '2023-02-01-preview',
#  'metadata': {'width': 1200, 'height': 602}}

# %%
main_caption = results['denseCaptionsResult']['values'][0]
main_caption

print("The main caption of the image is:",
      main_caption['text'],
      "with a confidence =", main_caption['confidence'])
# Out:
# The main caption of the image is: a fire truck and a car on fire with a confidence = 0.7798057198524475

# %%
print("\033[1;31;34mDense captions:\n")

for idx, value in enumerate(results['denseCaptionsResult']['values'], start=1):
    print(idx, value['text'], "=", round(value['confidence'], 3))
# Out:
# Dense captions:
#
# 1 a fire truck and a car on fire = 0.78
# 2 a fire truck on the road = 0.787
# 3 a car on fire with smoke coming out of the back = 0.796
# 4 a green sign with white text = 0.775
# 5 a green sign with a white arrow = 0.808
# 6 a car parked on the side of a road = 0.789
# 7 a person wearing a firefighter uniform = 0.69
# 8 a fire truck on the road = 0.798
# 9 firemen on the road with a fire truck = 0.635
# 10 a pole with a light on it = 0.67

# %%
images = glob.glob('cropped_1_*.*')

for image in images:
    os.remove(image)

img = cv2.cvtColor(cv2.imread('image1.jpg'), cv2.COLOR_BGR2RGB)
imageCopy = img.copy()

for value in results['denseCaptionsResult']['values']:
    densecaption = value['text']
    confidence = value['confidence']
    x = value['boundingBox']['x']
    y = value['boundingBox']['y']
    w = value['boundingBox']['w']
    h = value['boundingBox']['h']

    caption = f"{densecaption} = {round(confidence, 2)}"
    color = list(np.random.random(size=3) * 256)
    cv2.rectangle(img, (x, y), (x+w, y+h), color, 3)
    cv2.putText(img, caption, (x-80, int((y + y + h) / 2)),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    crop_img = imageCopy[y:y+h, x:x+w]
    cv2.imwrite("cropped_1_" + densecaption + '_' + str(confidence) +
                '.jpg', cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB))

plt.figure(figsize=(15, 12))
plt.axis('off')
plt.imshow(img)

plt.savefig("dense_captions_1.jpg")

# %%
images = glob.glob('cropped_1_*.*')
labels = [image.split('/')[-1] for image in images]

ipyplot.plot_images(images, max_images=15, img_width=150)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hPmWgZ5PVNpFmm6VGgpUXY {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hPmWgZ5PVNpFmm6VGgpUXY {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hPmWgZ5PVNpFmm6VGgpUXY {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hPmWgZ5PVNpFmm6VGgpUXY:checked ~ #ipyplot-html-viewer-textarea-hPmWgZ5PVNpFmm6VGgpUXY {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hPmWgZ5PVNpFmm6VGgpUXY:checked + #ipyplot-html-viewer-label-hPmWgZ5PVNpFmm6VGgpUXY:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-hPmWgZ5PVNpFmm6VGgpUXY">
#         <label id="ipyplot-html-viewer-label-hPmWgZ5PVNpFmm6VGgpUXY" for="ipyplot-html-viewer-toggle-hPmWgZ5PVNpFmm6VGgpUXY">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-hPmWgZ5PVNpFmm6VGgpUXY" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-mJN29KX4wsCjC6DhyRkxrq {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mJN29KX4wsCjC6DhyRkxrq">
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-BUtnYfUnPJFmhYBTJuYx2y" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a person wearing a firefighter uniform_0.6900274753570557.jpg</h4><img src="cropped_1_a person wearing a firefighter uniform_0.6900274753570557.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-BUtnYfUnPJFmhYBTJuYx2y">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-5Hap7UKLXc4ueQRKndY3oJ" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a pole with a light on it_0.6695119142532349.jpg</h4><img src="cropped_1_a pole with a light on it_0.6695119142532349.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-5Hap7UKLXc4ueQRKndY3oJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-cprByav2dn5GD5KphjNvBM" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a fire truck on the road_0.786890983581543.jpg</h4><img src="cropped_1_a fire truck on the road_0.786890983581543.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-cprByav2dn5GD5KphjNvBM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-QyasR4EtFmYRHiFj9cKzMS" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg</h4><img src="cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-QyasR4EtFmYRHiFj9cKzMS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-by7oBYz53NUMpqjoEiCyNv" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a fire truck and a car on fire_0.7798057198524475.jpg</h4><img src="cropped_1_a fire truck and a car on fire_0.7798057198524475.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-by7oBYz53NUMpqjoEiCyNv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-ZWFZYQuhFcF5mq3B4frQYo" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRk
#         <style>
#         #ipyplot-imgs-container-div-mJN29KX4wsCjC6DhyRkxrq {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mJN29KX4wsCjC6DhyRkxrq">
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-BUtnYfUnPJFmhYBTJuYx2y" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a person wearing a firefighter uniform_0.6900274753570557.jpg</h4><img src="cropped_1_a person wearing a firefighter uniform_0.6900274753570557.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-BUtnYfUnPJFmhYBTJuYx2y">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-5Hap7UKLXc4ueQRKndY3oJ" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a pole with a light on it_0.6695119142532349.jpg</h4><img src="cropped_1_a pole with a light on it_0.6695119142532349.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-5Hap7UKLXc4ueQRKndY3oJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-cprByav2dn5GD5KphjNvBM" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a fire truck on the road_0.786890983581543.jpg</h4><img src="cropped_1_a fire truck on the road_0.786890983581543.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-cprByav2dn5GD5KphjNvBM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-QyasR4EtFmYRHiFj9cKzMS" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg</h4><img src="cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-QyasR4EtFmYRHiFj9cKzMS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-by7oBYz53NUMpqjoEiCyNv" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a fire truck and a car on fire_0.7798057198524475.jpg</h4><img src="cropped_1_a fire truck and a car on fire_0.7798057198524475.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-by7oBYz53NUMpqjoEiCyNv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-ZWFZYQuhFcF5mq3B4frQYo" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a green sign with white text_0.7752601504325867.jpg</h4><img src="cropped_1_a green sign with white text_0.7752601504325867.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-ZWFZYQuhFcF5mq3B4frQYo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-Gix3QcLou6MoAJiZEyzKpU" class="ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a car parked on the side of a road_0.7894208431243896.jpg</h4><img src="cropped_1_a car parked on the side of a road_0.7894208431243896.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mJN29KX4wsCjC6DhyRkxrq-Gix3QcLou6MoAJiZEyzKpU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mJN29KX4wsCjC6DhyRkxrq">
#         <div id="ipyplot-cont

# %%
ipyplot.plot_class_tabs(images, labels, max_imgs_per_tab=10, img_width=200)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ebhsZfH32V8a62gTmVbBwz {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ebhsZfH32V8a62gTmVbBwz {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ebhsZfH32V8a62gTmVbBwz {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ebhsZfH32V8a62gTmVbBwz:checked ~ #ipyplot-html-viewer-textarea-ebhsZfH32V8a62gTmVbBwz {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ebhsZfH32V8a62gTmVbBwz:checked + #ipyplot-html-viewer-label-ebhsZfH32V8a62gTmVbBwz:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-ebhsZfH32V8a62gTmVbBwz">
#         <label id="ipyplot-html-viewer-label-ebhsZfH32V8a62gTmVbBwz" for="ipyplot-html-viewer-toggle-ebhsZfH32V8a62gTmVbBwz">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-ebhsZfH32V8a62gTmVbBwz" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H {
#                 display: none;
#             }
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H + label.ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H:checked + label.ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H ~ .tab {
#                 display: none
#             }
#     #tabEBvYxGT5Fm3YQeqtNZc9r2:checked ~ .tab.contentEBvYxGT5Fm3YQeqtNZc9r2,#tabD9kwhXFVnGYkxqYXCevjKR:checked ~ .tab.contentD9kwhXFVnGYkxqYXCevjKR,#tabkcZDMC6nis8mbCh8Tb4Gia:checked ~ .tab.contentkcZDMC6nis8mbCh8Tb4Gia,#tabVRghVJEeSgpm5wj2Rhdzax:checked ~ .tab.contentVRghVJEeSgpm5wj2Rhdzax,#tabMSRQrhJoTxC2KxK3XYMV6C:checked ~ .tab.contentMSRQrhJoTxC2KxK3XYMV6C,#tabEg6zxHthwEN8hSM9KpSyHh:checked ~ .tab.contentEg6zxHthwEN8hSM9KpSyHh,#tab4PWSjjguHXkMsfjekAcqo8:checked ~ .tab.content4PWSjjguHXkMsfjekAcqo8,#tabCkfELYV2WbXucVzgwoH43p:checked ~ .tab.contentCkfELYV2WbXucVzgwoH43p,#tabPJsBX4Wq2bYxBDnXH2QAzm:checked ~ .tab.contentPJsBX4Wq2bYxBDnXH2QAzm,#tabWJLS36AyVussNkDBeSpxtc:checked ~ .tab.contentWJLS36AyVussNkDBeSpxtc{ display: block; }</style><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabEBvYxGT5Fm3YQeqtNZc9r2" checked /><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabEBvYxGT5Fm3YQeqtNZc9r2">cropped_1_a car on fire with smoke coming out of the back_0.7961422204971313.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabD9kwhXFVnGYkxqYXCevjKR"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabD9kwhXFVnGYkxqYXCevjKR">cropped_1_a car parked on the side of a road_0.7894208431243896.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabkcZDMC6nis8mbCh8Tb4Gia"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabkcZDMC6nis8mbCh8Tb4Gia">cropped_1_a fire truck and a car on fire_0.7798057198524475.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabVRghVJEeSgpm5wj2Rhdzax"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabVRghVJEeSgpm5wj2Rhdzax">cropped_1_a fire truck on the road_0.786890983581543.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabMSRQrhJoTxC2KxK3XYMV6C"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabMSRQrhJoTxC2KxK3XYMV6C">cropped_1_a fire truck on the road_0.7976521253585815.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabEg6zxHthwEN8hSM9KpSyHh"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabEg6zxHthwEN8hSM9KpSyHh">cropped_1_a green sign with a white arrow_0.8083931803703308.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tab4PWSjjguHXkMsfjekAcqo8"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tab4PWSjjguHXkMsfjekAcqo8">cropped_1_a green sign with white text_0.7752601504325867.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabCkfELYV2WbXucVzgwoH43p"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabCkfELYV2WbXucVzgwoH43p">cropped_1_a person wearing a firefighter uniform_0.6900274753570557.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabPJsBX4Wq2bYxBDnXH2QAzm"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabPJsBX4Wq2bYxBDnXH2QAzm">cropped_1_a pole with a light on it_0.6695119142532349.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabWJLS36AyVussNkDBeSpxtc"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabWJLS36AyVussNkDBeSpxtc">cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg</label><div class="tab contentEBvYxGT5Fm3YQeqtNZc9r2">
#         <style>
#         #ipyplot-imgs-container-div-L4zS8aYKMUXL8utu6VchRC {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-L4zS8aYKMUXL8utu6VchRC {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC]:target span.ipyplot-img-
# <div>
#         <style>
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H {
#                 display: none;
#             }
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H + label.ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H:checked + label.ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H ~ .tab {
#                 display: none
#             }
#     #tabEBvYxGT5Fm3YQeqtNZc9r2:checked ~ .tab.contentEBvYxGT5Fm3YQeqtNZc9r2,#tabD9kwhXFVnGYkxqYXCevjKR:checked ~ .tab.contentD9kwhXFVnGYkxqYXCevjKR,#tabkcZDMC6nis8mbCh8Tb4Gia:checked ~ .tab.contentkcZDMC6nis8mbCh8Tb4Gia,#tabVRghVJEeSgpm5wj2Rhdzax:checked ~ .tab.contentVRghVJEeSgpm5wj2Rhdzax,#tabMSRQrhJoTxC2KxK3XYMV6C:checked ~ .tab.contentMSRQrhJoTxC2KxK3XYMV6C,#tabEg6zxHthwEN8hSM9KpSyHh:checked ~ .tab.contentEg6zxHthwEN8hSM9KpSyHh,#tab4PWSjjguHXkMsfjekAcqo8:checked ~ .tab.content4PWSjjguHXkMsfjekAcqo8,#tabCkfELYV2WbXucVzgwoH43p:checked ~ .tab.contentCkfELYV2WbXucVzgwoH43p,#tabPJsBX4Wq2bYxBDnXH2QAzm:checked ~ .tab.contentPJsBX4Wq2bYxBDnXH2QAzm,#tabWJLS36AyVussNkDBeSpxtc:checked ~ .tab.contentWJLS36AyVussNkDBeSpxtc{ display: block; }</style><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabEBvYxGT5Fm3YQeqtNZc9r2" checked /><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabEBvYxGT5Fm3YQeqtNZc9r2">cropped_1_a car on fire with smoke coming out of the back_0.7961422204971313.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabD9kwhXFVnGYkxqYXCevjKR"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabD9kwhXFVnGYkxqYXCevjKR">cropped_1_a car parked on the side of a road_0.7894208431243896.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabkcZDMC6nis8mbCh8Tb4Gia"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabkcZDMC6nis8mbCh8Tb4Gia">cropped_1_a fire truck and a car on fire_0.7798057198524475.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabVRghVJEeSgpm5wj2Rhdzax"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabVRghVJEeSgpm5wj2Rhdzax">cropped_1_a fire truck on the road_0.786890983581543.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabMSRQrhJoTxC2KxK3XYMV6C"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabMSRQrhJoTxC2KxK3XYMV6C">cropped_1_a fire truck on the road_0.7976521253585815.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabEg6zxHthwEN8hSM9KpSyHh"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabEg6zxHthwEN8hSM9KpSyHh">cropped_1_a green sign with a white arrow_0.8083931803703308.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tab4PWSjjguHXkMsfjekAcqo8"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tab4PWSjjguHXkMsfjekAcqo8">cropped_1_a green sign with white text_0.7752601504325867.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabCkfELYV2WbXucVzgwoH43p"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabCkfELYV2WbXucVzgwoH43p">cropped_1_a person wearing a firefighter uniform_0.6900274753570557.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabPJsBX4Wq2bYxBDnXH2QAzm"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabPJsBX4Wq2bYxBDnXH2QAzm">cropped_1_a pole with a light on it_0.6695119142532349.jpg</label><input class="ipyplot-tab-Be7YUf2SgLJXsruT2FyF2H" type="radio" name="tabs-Be7YUf2SgLJXsruT2FyF2H" id="tabWJLS36AyVussNkDBeSpxtc"/><label class="ipyplot-tab-label-Be7YUf2SgLJXsruT2FyF2H" for="tabWJLS36AyVussNkDBeSpxtc">cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg</label><div class="tab contentEBvYxGT5Fm3YQeqtNZc9r2">
#         <style>
#         #ipyplot-imgs-container-div-L4zS8aYKMUXL8utu6VchRC {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-L4zS8aYKMUXL8utu6VchRC {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-L4zS8aYKMUXL8utu6VchRC">
#     <div class="ipyplot-placeholder-div-L4zS8aYKMUXL8utu6VchRC">
#         <div id="ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC-3NmUw5p2mv2yCQe7LvZwML" class="ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a car on fire with smoke coming out of the back_0.7961422204971313.jpg</h4><img src="cropped_1_a car on fire with smoke coming out of the back_0.7961422204971313.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L4zS8aYKMUXL8utu6VchRC-3NmUw5p2mv2yCQe7LvZwML">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentD9kwhXFVnGYkxqYXCevjKR">
#         <style>
#         #ipyplot-imgs-container-div-bT7ErF4uaVNuPZUavExo93 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bT7ErF4uaVNuPZUavExo93 {
#             width: 200px;
#             display: inline-block;
