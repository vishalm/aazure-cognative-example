# %% [markdown]
# # Image Analysis V4.0 Captioning and Dense Captioning (public preview)
#
# "Caption" replaces "Describe" in V4.0 as the significantly improved image captioning feature rich with details and sematic understanding.
#
# - Dense Captions provides more detail by generating one sentence descriptions of up to 10 regions of the image in addition to describing the whole image.
# - Dense Captions also returns bounding box coordinates of the described image regions.
# - There's also a new gender-neutral parameter to allow customers to choose whether to enable probabilistic gender inference for alt-text and Seeing AI applications.
# - Automatically deliver rich captions, accessible alt-text, SEO optimization, and intelligent photo curation to support digital content.
#
# https://learn.microsoft.com/en-us/azure/cognitive-services/computer-vision/concept-describe-images-40?tabs=image

# %%
import cv2
import json
import datetime
import requests
import sys
import random
import urllib.request
import numpy as np
import ipyplot
import glob

from io import BytesIO
from PIL import Image
from matplotlib import pyplot as plt

# %%
sys.version
# Out:
# '3.11.8 (main, Mar 18 2024, 11:56:40) [Clang 15.0.0 (clang-1500.3.9.4)]'

# %%
print("Today is", datetime.datetime.today())
# Out:
# Today is 2024-08-15 12:04:51.463184

# %%
import os

myendpoint=os.environ['MY_URL']
myendpoint_key1=os.environ['MY_KEY']
endpoint = myendpoint+"computervision/imageanalysis:analyze?api-version=2023-02-01-preview&features=denseCaptions&language=en"

headers = {
    'Content-type': 'application/json',
    'Ocp-Apim-Subscription-Key': myendpoint_key1
}

# %%
imageurl = 'https://github.com/retkowsky/images/blob/master/car%20on%20fire.jpg?raw=true'

r = requests.get(imageurl)
img = Image.open(BytesIO(r.content))
img

img.save("image1.jpg")

# %%
r = requests.post(endpoint,
                  data=json.dumps({'url': imageurl}),
                  headers=headers)

results = r.json()
results
# Out:
# {'denseCaptionsResult': {'values': [{'text': 'a fire truck and a car on fire',
#     'confidence': 0.7801371216773987,
#     'boundingBox': {'x': 0, 'y': 0, 'w': 1200, 'h': 602}},
#    {'text': 'a fire truck on the road',
#     'confidence': 0.786890983581543,
#     'boundingBox': {'x': 332, 'y': 322, 'w': 185, 'h': 114}},
#    {'text': 'a car on fire with smoke coming out of the back',
#     'confidence': 0.7962431311607361,
#     'boundingBox': {'x': 670, 'y': 401, 'w': 187, 'h': 117}},
#    {'text': 'a green sign with white text',
#     'confidence': 0.7752601504325867,
#     'boundingBox': {'x': 199, 'y': 301, 'w': 73, 'h': 64}},
#    {'text': 'a green sign with a white arrow',
#     'confidence': 0.8083931803703308,
#     'boundingBox': {'x': 199, 'y': 300, 'w': 73, 'h': 152}},
#    {'text': 'a car parked on the side of a road',
#     'confidence': 0.7928762435913086,
#     'boundingBox': {'x': 793, 'y': 244, 'w': 398, 'h': 349}},
#    {'text': 'a person wearing a firefighter uniform',
#     'confidence': 0.6902769207954407,
#     'boundingBox': {'x': 454, 'y': 405, 'w': 51, 'h': 70}},
#    {'text': 'a fire truck on the road',
#     'confidence': 0.7956277132034302,
#     'boundingBox': {'x': 96, 'y': 72, 'w': 387, 'h': 346}},
#    {'text': 'firemen on the road with a fire truck',
#     'confidence': 0.6349040865898132,
#     'boundingBox': {'x': 75, 'y': 150, 'w': 728, 'h': 431}},
#    {'text': 'a pole with a light on it',
#     'confidence': 0.6698022484779358,
#     'boundingBox': {'x': 1013, 'y': 1, 'w': 122, 'h': 287}}]},
#  'modelVersion': '2023-02-01-preview',
#  'metadata': {'width': 1200, 'height': 602}}

# %%
main_caption = results['denseCaptionsResult']['values'][0]
main_caption

print("The main caption of the image is:",
      main_caption['text'],
      "with a confidence =", main_caption['confidence'])
# Out:
# The main caption of the image is: a fire truck and a car on fire with a confidence = 0.7801371216773987

# %%
print("\033[1;31;34mDense captions:\n")

for idx, value in enumerate(results['denseCaptionsResult']['values'], start=1):
    print(idx, value['text'], "=", round(value['confidence'], 3))
# Out:
# Dense captions:
#
# 1 a fire truck and a car on fire = 0.78
# 2 a fire truck on the road = 0.787
# 3 a car on fire with smoke coming out of the back = 0.796
# 4 a green sign with white text = 0.775
# 5 a green sign with a white arrow = 0.808
# 6 a car parked on the side of a road = 0.793
# 7 a person wearing a firefighter uniform = 0.69
# 8 a fire truck on the road = 0.796
# 9 firemen on the road with a fire truck = 0.635
# 10 a pole with a light on it = 0.67

# %%
images = glob.glob('cropped_1_*.*')

for image in images:
    os.remove(image)

img = cv2.cvtColor(cv2.imread('image1.jpg'), cv2.COLOR_BGR2RGB)
imageCopy = img.copy()

for value in results['denseCaptionsResult']['values']:
    densecaption = value['text']
    confidence = value['confidence']
    x = value['boundingBox']['x']
    y = value['boundingBox']['y']
    w = value['boundingBox']['w']
    h = value['boundingBox']['h']

    caption = f"{densecaption} = {round(confidence, 2)}"
    color = list(np.random.random(size=3) * 256)
    cv2.rectangle(img, (x, y), (x+w, y+h), color, 3)
    cv2.putText(img, caption, (x-80, int((y + y + h) / 2)),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    crop_img = imageCopy[y:y+h, x:x+w]
    cv2.imwrite("cropped_1_" + densecaption + '_' + str(confidence) +
                '.jpg', cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB))

plt.figure(figsize=(15, 12))
plt.axis('off')
plt.imshow(img)

plt.savefig("dense_captions_1.jpg")

# %%
images = glob.glob('cropped_1_*.*')
labels = [image.split('/')[-1] for image in images]

ipyplot.plot_images(images, max_images=15, img_width=150)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-f4cBnQqgr6c6GuEkQsjgp5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-f4cBnQqgr6c6GuEkQsjgp5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-f4cBnQqgr6c6GuEkQsjgp5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-f4cBnQqgr6c6GuEkQsjgp5:checked ~ #ipyplot-html-viewer-textarea-f4cBnQqgr6c6GuEkQsjgp5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-f4cBnQqgr6c6GuEkQsjgp5:checked + #ipyplot-html-viewer-label-f4cBnQqgr6c6GuEkQsjgp5:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-f4cBnQqgr6c6GuEkQsjgp5">
#         <label id="ipyplot-html-viewer-label-f4cBnQqgr6c6GuEkQsjgp5" for="ipyplot-html-viewer-toggle-f4cBnQqgr6c6GuEkQsjgp5">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-f4cBnQqgr6c6GuEkQsjgp5" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-SxTJdjDE9znoDJ5HBcAiz9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-SxTJdjDE9znoDJ5HBcAiz9">
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-MghzFztQdTTXujfi4diU2Z" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a fire truck and a car on fire_0.7801371216773987.jpg</h4><img src="cropped_1_a fire truck and a car on fire_0.7801371216773987.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-MghzFztQdTTXujfi4diU2Z">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-dCFGmeaGEDCYx3A2NLvTr7" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a person wearing a firefighter uniform_0.6902769207954407.jpg</h4><img src="cropped_1_a person wearing a firefighter uniform_0.6902769207954407.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-dCFGmeaGEDCYx3A2NLvTr7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-3zWeKamG9A3PTCngu5GpLM" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a car parked on the side of a road_0.7928762435913086.jpg</h4><img src="cropped_1_a car parked on the side of a road_0.7928762435913086.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-3zWeKamG9A3PTCngu5GpLM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-VkR3cFSBDsvba7jaYiRzU6" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a fire truck on the road_0.786890983581543.jpg</h4><img src="cropped_1_a fire truck on the road_0.786890983581543.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-VkR3cFSBDsvba7jaYiRzU6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-Md7qCuv9wFKybiPYVcgEcZ" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg</h4><img src="cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-Md7qCuv9wFKybiPYVcgEcZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-eRqg8Tdkuuo43biAPaewSD" class="ipyplot-content-div-S
#         <style>
#         #ipyplot-imgs-container-div-SxTJdjDE9znoDJ5HBcAiz9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-SxTJdjDE9znoDJ5HBcAiz9">
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-MghzFztQdTTXujfi4diU2Z" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a fire truck and a car on fire_0.7801371216773987.jpg</h4><img src="cropped_1_a fire truck and a car on fire_0.7801371216773987.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-MghzFztQdTTXujfi4diU2Z">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-dCFGmeaGEDCYx3A2NLvTr7" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a person wearing a firefighter uniform_0.6902769207954407.jpg</h4><img src="cropped_1_a person wearing a firefighter uniform_0.6902769207954407.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-dCFGmeaGEDCYx3A2NLvTr7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-3zWeKamG9A3PTCngu5GpLM" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a car parked on the side of a road_0.7928762435913086.jpg</h4><img src="cropped_1_a car parked on the side of a road_0.7928762435913086.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-3zWeKamG9A3PTCngu5GpLM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-VkR3cFSBDsvba7jaYiRzU6" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a fire truck on the road_0.786890983581543.jpg</h4><img src="cropped_1_a fire truck on the road_0.786890983581543.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-VkR3cFSBDsvba7jaYiRzU6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-Md7qCuv9wFKybiPYVcgEcZ" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg</h4><img src="cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-Md7qCuv9wFKybiPYVcgEcZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-eRqg8Tdkuuo43biAPaewSD" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a green sign with white text_0.7752601504325867.jpg</h4><img src="cropped_1_a green sign with white text_0.7752601504325867.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-eRqg8Tdkuuo43biAPaewSD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-KbowAckQ7vo7LkkZ9BLuwN" class="ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a green sign with a white arrow_0.8083931803703308.jpg</h4><img src="cropped_1_a green sign with a white arrow_0.8083931803703308.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SxTJdjDE9znoDJ5HBcAiz9-KbowAckQ7vo7LkkZ9BLuwN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SxTJdjDE9znoDJ5HBcAiz9">
#         <div id="

# %%
ipyplot.plot_class_tabs(images, labels, max_imgs_per_tab=10, img_width=200)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-PLM33wGKawEp8DYu6GESX4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PLM33wGKawEp8DYu6GESX4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PLM33wGKawEp8DYu6GESX4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PLM33wGKawEp8DYu6GESX4:checked ~ #ipyplot-html-viewer-textarea-PLM33wGKawEp8DYu6GESX4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PLM33wGKawEp8DYu6GESX4:checked + #ipyplot-html-viewer-label-PLM33wGKawEp8DYu6GESX4:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-PLM33wGKawEp8DYu6GESX4">
#         <label id="ipyplot-html-viewer-label-PLM33wGKawEp8DYu6GESX4" for="ipyplot-html-viewer-toggle-PLM33wGKawEp8DYu6GESX4">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-PLM33wGKawEp8DYu6GESX4" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM {
#                 display: none;
#             }
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM + label.ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM:checked + label.ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM ~ .tab {
#                 display: none
#             }
#     #tabUgaVZWSmsmVdGx5NcnyrQU:checked ~ .tab.contentUgaVZWSmsmVdGx5NcnyrQU,#tabLXdNSiN5RQcQfNPzXhxkqn:checked ~ .tab.contentLXdNSiN5RQcQfNPzXhxkqn,#tabTAn96TRS6aLeusVxRmPBnM:checked ~ .tab.contentTAn96TRS6aLeusVxRmPBnM,#tabguDUs6euDg8ys2vZD42Eas:checked ~ .tab.contentguDUs6euDg8ys2vZD42Eas,#tabQHQ3cm9BQ5N4M7ewacTdxZ:checked ~ .tab.contentQHQ3cm9BQ5N4M7ewacTdxZ,#tabfMi4HTBgpjB7hSsZBLRZre:checked ~ .tab.contentfMi4HTBgpjB7hSsZBLRZre,#tabNEPH9pgaaNFBFRadTWBDQr:checked ~ .tab.contentNEPH9pgaaNFBFRadTWBDQr,#tab2CjCvWHeFFuPGo5RLvvGiF:checked ~ .tab.content2CjCvWHeFFuPGo5RLvvGiF,#tabgyjEUpe7qP6xUtdkwRgJ5t:checked ~ .tab.contentgyjEUpe7qP6xUtdkwRgJ5t,#tabmGjXPB9StePsK7EeJ5CMXB:checked ~ .tab.contentmGjXPB9StePsK7EeJ5CMXB{ display: block; }</style><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabUgaVZWSmsmVdGx5NcnyrQU" checked /><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabUgaVZWSmsmVdGx5NcnyrQU">cropped_1_a car on fire with smoke coming out of the back_0.7962431311607361.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabLXdNSiN5RQcQfNPzXhxkqn"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabLXdNSiN5RQcQfNPzXhxkqn">cropped_1_a car parked on the side of a road_0.7928762435913086.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabTAn96TRS6aLeusVxRmPBnM"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabTAn96TRS6aLeusVxRmPBnM">cropped_1_a fire truck and a car on fire_0.7801371216773987.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabguDUs6euDg8ys2vZD42Eas"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabguDUs6euDg8ys2vZD42Eas">cropped_1_a fire truck on the road_0.786890983581543.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabQHQ3cm9BQ5N4M7ewacTdxZ"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabQHQ3cm9BQ5N4M7ewacTdxZ">cropped_1_a fire truck on the road_0.7956277132034302.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabfMi4HTBgpjB7hSsZBLRZre"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabfMi4HTBgpjB7hSsZBLRZre">cropped_1_a green sign with a white arrow_0.8083931803703308.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabNEPH9pgaaNFBFRadTWBDQr"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabNEPH9pgaaNFBFRadTWBDQr">cropped_1_a green sign with white text_0.7752601504325867.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tab2CjCvWHeFFuPGo5RLvvGiF"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tab2CjCvWHeFFuPGo5RLvvGiF">cropped_1_a person wearing a firefighter uniform_0.6902769207954407.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabgyjEUpe7qP6xUtdkwRgJ5t"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabgyjEUpe7qP6xUtdkwRgJ5t">cropped_1_a pole with a light on it_0.6698022484779358.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabmGjXPB9StePsK7EeJ5CMXB"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabmGjXPB9StePsK7EeJ5CMXB">cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg</label><div class="tab contentUgaVZWSmsmVdGx5NcnyrQU">
#         <style>
#         #ipyplot-imgs-container-div-fgwbBKGAF6t3V9aERBRQze {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fgwbBKGAF6t3V9aERBRQze {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze]:target span.ipyplot-img-
# <div>
#         <style>
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM {
#                 display: none;
#             }
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM + label.ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM:checked + label.ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM ~ .tab {
#                 display: none
#             }
#     #tabUgaVZWSmsmVdGx5NcnyrQU:checked ~ .tab.contentUgaVZWSmsmVdGx5NcnyrQU,#tabLXdNSiN5RQcQfNPzXhxkqn:checked ~ .tab.contentLXdNSiN5RQcQfNPzXhxkqn,#tabTAn96TRS6aLeusVxRmPBnM:checked ~ .tab.contentTAn96TRS6aLeusVxRmPBnM,#tabguDUs6euDg8ys2vZD42Eas:checked ~ .tab.contentguDUs6euDg8ys2vZD42Eas,#tabQHQ3cm9BQ5N4M7ewacTdxZ:checked ~ .tab.contentQHQ3cm9BQ5N4M7ewacTdxZ,#tabfMi4HTBgpjB7hSsZBLRZre:checked ~ .tab.contentfMi4HTBgpjB7hSsZBLRZre,#tabNEPH9pgaaNFBFRadTWBDQr:checked ~ .tab.contentNEPH9pgaaNFBFRadTWBDQr,#tab2CjCvWHeFFuPGo5RLvvGiF:checked ~ .tab.content2CjCvWHeFFuPGo5RLvvGiF,#tabgyjEUpe7qP6xUtdkwRgJ5t:checked ~ .tab.contentgyjEUpe7qP6xUtdkwRgJ5t,#tabmGjXPB9StePsK7EeJ5CMXB:checked ~ .tab.contentmGjXPB9StePsK7EeJ5CMXB{ display: block; }</style><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabUgaVZWSmsmVdGx5NcnyrQU" checked /><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabUgaVZWSmsmVdGx5NcnyrQU">cropped_1_a car on fire with smoke coming out of the back_0.7962431311607361.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabLXdNSiN5RQcQfNPzXhxkqn"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabLXdNSiN5RQcQfNPzXhxkqn">cropped_1_a car parked on the side of a road_0.7928762435913086.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabTAn96TRS6aLeusVxRmPBnM"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabTAn96TRS6aLeusVxRmPBnM">cropped_1_a fire truck and a car on fire_0.7801371216773987.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabguDUs6euDg8ys2vZD42Eas"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabguDUs6euDg8ys2vZD42Eas">cropped_1_a fire truck on the road_0.786890983581543.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabQHQ3cm9BQ5N4M7ewacTdxZ"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabQHQ3cm9BQ5N4M7ewacTdxZ">cropped_1_a fire truck on the road_0.7956277132034302.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabfMi4HTBgpjB7hSsZBLRZre"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabfMi4HTBgpjB7hSsZBLRZre">cropped_1_a green sign with a white arrow_0.8083931803703308.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabNEPH9pgaaNFBFRadTWBDQr"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabNEPH9pgaaNFBFRadTWBDQr">cropped_1_a green sign with white text_0.7752601504325867.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tab2CjCvWHeFFuPGo5RLvvGiF"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tab2CjCvWHeFFuPGo5RLvvGiF">cropped_1_a person wearing a firefighter uniform_0.6902769207954407.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabgyjEUpe7qP6xUtdkwRgJ5t"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabgyjEUpe7qP6xUtdkwRgJ5t">cropped_1_a pole with a light on it_0.6698022484779358.jpg</label><input class="ipyplot-tab-bXLR3ikEcnYUtGw3ZMcUBM" type="radio" name="tabs-bXLR3ikEcnYUtGw3ZMcUBM" id="tabmGjXPB9StePsK7EeJ5CMXB"/><label class="ipyplot-tab-label-bXLR3ikEcnYUtGw3ZMcUBM" for="tabmGjXPB9StePsK7EeJ5CMXB">cropped_1_firemen on the road with a fire truck_0.6349040865898132.jpg</label><div class="tab contentUgaVZWSmsmVdGx5NcnyrQU">
#         <style>
#         #ipyplot-imgs-container-div-fgwbBKGAF6t3V9aERBRQze {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fgwbBKGAF6t3V9aERBRQze {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fgwbBKGAF6t3V9aERBRQze">
#     <div class="ipyplot-placeholder-div-fgwbBKGAF6t3V9aERBRQze">
#         <div id="ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze-2xniv94X4vJLhZSxjumpkr" class="ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">cropped_1_a car on fire with smoke coming out of the back_0.7962431311607361.jpg</h4><img src="cropped_1_a car on fire with smoke coming out of the back_0.7962431311607361.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fgwbBKGAF6t3V9aERBRQze-2xniv94X4vJLhZSxjumpkr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentLXdNSiN5RQcQfNPzXhxkqn">
#         <style>
#         #ipyplot-imgs-container-div-QQQyiPDbXFuiwyLJoWfUmP {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-QQQyiPDbXFuiwyLJoWfUmP {
#             width: 200px;
#             display: inline-block;
